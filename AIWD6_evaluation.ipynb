# %% [markdown]
# ## Imports

# %%
import time
import torch
from torch.utils.data import DataLoader, Dataset
from utils import validation
from transweather_model import Transweather
import sys
import os
from PIL import Image
from torchvision.transforms import Compose, ToTensor, Normalize
import numpy as np

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Generate input.txt and gt.txt files for each image from img0 to img9 for each subfolder

# %%
import os

main_folder = "./dataset/AIWD6/Sunny_to_Rainy/"

subfolders = os.listdir(main_folder)
subfolders.sort()

for i in range(0, 10):  # For each image from img0 to img9
    input_file = open(f'./dataset/AIWD6/meta/Sunny_to_Rainy/input{i}.txt', 'w')
    gt_file = open('./dataset/AIWD6/meta/Sunny_to_Rainy/gt.txt', 'w')

    for subfolder in subfolders:
        if os.path.exists(os.path.join(main_folder, subfolder, f'{i}.png')):
            img_path = os.path.join(main_folder, subfolder, f'{i}.png')
            gt_path = os.path.join(main_folder, subfolder, 'Image1.png')

        input_file.write(img_path + '\n')
        gt_file.write(gt_path + '\n')

    input_file.close()  
    gt_file.close()

# %% [markdown]
# ## Dataloader

# %%
class ValData(Dataset):
    def __init__(self, val_input_filename ,val_gt_filename):
        super().__init__()

        with open(val_input_filename) as f:
            contents = f.readlines()
            input_names = [i.strip() for i in contents]
        
        with open(val_gt_filename) as f:
            contents = f.readlines()
            gt_names = [i.strip() for i in contents]
            
            
        self.input_names = input_names
        self.gt_names = gt_names

    def get_images(self, index):
        
        input_name = self.input_names[index]
        gt_name = self.gt_names[index]

        input_img = Image.open(input_name)
        gt_img = Image.open(gt_name)

        # Resizing image in the multiple of 16"
        wd_new,ht_new = input_img.size
        if ht_new>wd_new and ht_new>1024:
            wd_new = int(np.ceil(wd_new*1024/ht_new))
            ht_new = 1024
        elif ht_new<=wd_new and wd_new>1024:
            ht_new = int(np.ceil(ht_new*1024/wd_new))
            wd_new = 1024
        wd_new = int(16*np.ceil(wd_new/16.0))
        ht_new = int(16*np.ceil(ht_new/16.0))
        input_img = input_img.resize((wd_new,ht_new), Image.ANTIALIAS)
        gt_img = gt_img.resize((wd_new, ht_new), Image.ANTIALIAS)

        # --- Transform to tensor --- #
        transform_input = Compose([ToTensor(), Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])
        transform_gt = Compose([ToTensor()])
        input_im = transform_input(input_img)
        gt = transform_gt(gt_img)

        return input_im, gt, input_name

    def __getitem__(self, index):
        res = self.get_images(index)
        return res

    def __len__(self):
        return len(self.input_names)

# %% [markdown]
# ## Loading model

# %%
net = Transweather()
exp_name = "Transweather_scratch_val_on_testset_a/"

try:
    ckp_path = "./{}best.pth".format(exp_name)
    ckp = torch.load(ckp_path)
    net.load_state_dict(ckp)
    print("Model loaded successfully")
except:
    print("Unsuccessful in loading model")
    sys.exit(1)
# Out:
# Model loaded successfully

# %% [markdown]
# ## Evaluation

# %%
val_batch_size = 32
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
net.to(device)
net.eval()



meta_folder = "./dataset/AIWD6/meta/"
subfolders = sorted(os.listdir(meta_folder))

print('--- Evaluation starts! ---')

for subfolder in subfolders:
    input_files = sorted(os.listdir(meta_folder+subfolder+"/"))[1:]
    
    for input_file in input_files:
        val_input_filename = meta_folder+subfolder+"/"+input_file
        val_gt_filename = meta_folder+subfolder+"/gt.txt"

        dataset = ValData(val_input_filename,val_gt_filename)
        val_data_loader = DataLoader(dataset, batch_size=val_batch_size, 
                                 shuffle=False, num_workers = 4, pin_memory = True)

        
        start_time = time.time()
        val_psnr, val_ssim = validation(net, val_data_loader, device, exp_name, save_tag=False)
        end_time = time.time() - start_time
        

        print("Folder: ", subfolder, "\nImage: ", input_file)
        print(f"Extracted {len(dataset)} images")
        print('val_psnr: {0:.2f}, val_ssim: {1:.4f}'.format(val_psnr, val_ssim))
        print('validation time is {0:.4f}'.format(end_time))
        print("*"*100)

print('--- Evaluation finish! ---')
# Out:
# --- Evaluation starts! ---
# Folder:  Cloudy_to_Rainy
# Image:  input0.txt
# Extracted 293 images
# val_psnr: 28.42, val_ssim: 0.9128
# validation time is 4.3073
# ****************************************************************************************************
# Folder:  Cloudy_to_Rainy
# Image:  input1.txt
# Extracted 293 images
# val_psnr: 30.16, val_ssim: 0.9242
# validation time is 3.6657
# ****************************************************************************************************
# Folder:  Cloudy_to_Rainy
# Image:  input2.txt
# Extracted 293 images
# val_psnr: 29.44, val_ssim: 0.9210
# validation time is 3.7255
# ****************************************************************************************************
# Folder:  Cloudy_to_Rainy
# Image:  input3.txt
# Extracted 293 images
# val_psnr: 26.82, val_ssim: 0.9028
# validation time is 4.1622
# ****************************************************************************************************
# Folder:  Cloudy_to_Rainy
# Image:  input4.txt
# Extracted 293 images
# val_psnr: 23.91, val_ssim: 0.8717
# validation time is 4.4290
# ****************************************************************************************************
# Folder:  Cloudy_to_Rainy
# Image:  input5.txt
# Extracted 293 images
# val_psnr: 21.35, val_ssim: 0.8358
# validation time is 4.0356
# ****************************************************************************************************
# Folder:  Cloudy_to_Rainy
# Image:  input6.txt
# Extracted 293 images
# val_psnr: 19.31, val_ssim: 0.8011
# validation time is 4.0644
# ****************************************************************************************************
# Folder:  Cloudy_to_Rainy
# Image:  input7.txt
# Extracted 293 images
# val_psnr: 17.68, val_ssim: 0.7663
# validation time is 4.0502
# ****************************************************************************************************
# Folder:  Cloudy_to_Rainy
# Image:  input8.txt
# Extracted 293 images
# val_psnr: 16.38, val_ssim: 0.7316
# validation time is 5.7393
# ****************************************************************************************************
# Folder:  Cloudy_to_Rainy
# Image:  input9.txt
# Extracted 293 images
# val_psnr: 15.35, val_ssim: 0.6968
# validation time is 4.2101
# ****************************************************************************************************
# Folder:  Foggy_to_Sunny
# Image:  input0.txt
# Extracted 293 images
# val_psnr: 11.56, val_ssim: 0.6349
# validation time is 4.1213
# ****************************************************************************************************
# Folder:  Foggy_to_Sunny
# Image:  input1.txt
# Extracted 293 images
# val_psnr: 12.54, val_ssim: 0.6783
# validation time is 4.1429
# ****************************************************************************************************
# Folder:  Foggy_to_Sunny
# Image:  input2.txt
# Extracted 293 images
# val_psnr: 13.76, val_ssim: 0.7215
# validation time is 3.9441
# ****************************************************************************************************
# Folder:  Foggy_to_Sunny
# Image:  input3.txt
# Extracted 293 images
# val_psnr: 15.31, val_ssim: 0.7664
# validation time is 3.9607
# ****************************************************************************************************
# Folder:  Foggy_to_Sunny
# Image:  input4.txt
# Extracted 293 images
# val_psnr: 17.22, val_ssim: 0.8110
# validation time is 3.9090
# ****************************************************************************************************
# Folder:  Foggy_to_Sunny
# Image:  input5.txt
# Extracted 293 images
# val_psnr: 19.56, val_ssim: 0.8531
# validation time is 4.4828
# ****************************************************************************************************
# Folder:  Foggy_to_Sunny
# Image:  input6.txt
# Extracted 293 images
# val_psnr: 22.38, val_ssim: 0.8897
# validation time is 4.4030
# ****************************************************************************************************
# Folder:  Foggy_to_Sunny
# Image:  input7.txt
# Extracted 293 images
# val_psnr: 25.43, val_ssim: 0.9167
# validation time is 4.6942
# ****************************************************************************************************
# Folder:  Foggy_to_Sunny
# Image:  input8.txt
# Extracted 293 images
# val_psnr: 27.63, val_ssim: 0.9301
# validation time is 4.1221
# ****************************************************************************************************
# Folder:  Foggy_to_Sunny
# Image:  input9.txt
# Extracted 293 images
# val_psnr: 28.27, val_ssim: 0.9278
# validation time is 4.3293
# ****************************************************************************************************
# Folder:  Rainy_to_Cloudy
# Image:  input0.txt
# Extracted 293 images
# val_psnr: 15.18, val_ssim: 0.6927
# validation time is 3.9952
# ****************************************************************************************************
# Folder:  Rainy_to_Cloudy
# Image:  input1.txt
# Extracted 293 images
# val_psnr: 16.17, val_ssim: 0.7262
# validation time is 4.0786
# ****************************************************************************************************
# Folder:  Rainy_to_Cloudy
# Image:  input2.txt
# Extracted 293 images
# val_psnr: 17.40, val_ssim: 0.7600
# validation time is 4.4034
# ****************************************************************************************************
# Folder:  Rainy_to_Cloudy
# Image:  input3.txt
# Extracted 293 images
# val_psnr: 18.95, val_ssim: 0.7929
# validation time is 5.2863
# ****************************************************************************************************
# Folder:  Rainy_to_Cloudy
# Image:  input4.txt
# Extracted 293 images
# val_psnr: 20.87, val_ssim: 0.8274
# validation time is 4.6627
# ****************************************************************************************************
# Folder:  Rainy_to_Cloudy
# Image:  input5.txt
# Extracted 293 images
# val_psnr: 23.29, val_ssim: 0.8649
# validation time is 3.9819
# ****************************************************************************************************
# Folder:  Rainy_to_Cloudy
# Image:  input6.txt
# Extracted 293 images
# val_psnr: 26.18, val_ssim: 0.8994
# validation time is 3.9855
# ****************************************************************************************************
# Folder:  Rainy_to_Cloudy
# Image:  input7.txt
# Extracted 293 images
# val_psnr: 29.03, val_ssim: 0.9219
# validation time is 4.2356
# ****************************************************************************************************
# Folder:  Rainy_to_Cloudy
# Image:  input8.txt
# Extracted 293 images
# val_psnr: 30.15, val_ssim: 0.9286
# validation time is 4.4099
# ****************************************************************************************************
# Folder:  Rainy_to_Cloudy
# Image:  input9.txt
# Extracted 293 images
# val_psnr: 28.60, val_ssim: 0.9194
# validation time is 4.0731
# ****************************************************************************************************
# Folder:  Rainy_to_Sunny
# Image:  input0.txt
# Extracted 239 images
# val_psnr: 8.05, val_ssim: 0.3811
# validation time is 4.4056
# ****************************************************************************************************
# Folder:  Rainy_to_Sunny
# Image:  input1.txt
# Extracted 239 images
# val_psnr: 8.84, val_ssim: 0.4135
# validation time is 4.9991
# ****************************************************************************************************
# Folder:  Rainy_to_Sunny
# Image:  input2.txt
# Extracted 239 images
# val_psnr: 9.84, val_ssim: 0.4508
# validation time is 4.2470
# ****************************************************************************************************
# Folder:  Rainy_to_Sunny
# Image:  input3.txt
# Extracted 239 images
# val_psnr: 11.15, val_ssim: 0.4971
# validation time is 4.1598
# ****************************************************************************************************
# Folder:  Rainy_to_Sunny
# Image:  input4.txt
# Extracted 239 images
# val_psnr: 12.88, val_ssim: 0.5564
# validation time is 4.9058
# ****************************************************************************************************
# Folder:  Rainy_to_Sunny
# Image:  input5.txt
# Extracted 239 images
# val_psnr: 15.13, val_ssim: 0.6293
# validation time is 4.4033
# ****************************************************************************************************
# Folder:  Rainy_to_Sunny
# Image:  input6.txt
# Extracted 239 images
# val_psnr: 18.12, val_ssim: 0.7125
# validation time is 5.0806
# ****************************************************************************************************
# Folder:  Rainy_to_Sunny
# Image:  input7.txt
# Extracted 239 images
# val_psnr: 22.11, val_ssim: 0.7965
# validation time is 4.0702
# ****************************************************************************************************
# Folder:  Rainy_to_Sunny
# Image:  input8.txt
# Extracted 239 images
# val_psnr: 26.70, val_ssim: 0.8638
# validation time is 3.7467
# ****************************************************************************************************
# Folder:  Rainy_to_Sunny
# Image:  input9.txt
# Extracted 239 images
# val_psnr: 28.12, val_ssim: 0.8880
# validation time is 4.2518
# ****************************************************************************************************
# Folder:  Sunny_to_Foggy
# Image:  input0.txt
# Extracted 293 images
# val_psnr: 28.64, val_ssim: 0.9258
# validation time is 7.8265
# ****************************************************************************************************
# Folder:  Sunny_to_Foggy
# Image:  input1.txt
# Extracted 293 images
# val_psnr: 27.76, val_ssim: 0.9256
# validation time is 6.0946
# ****************************************************************************************************
# Folder:  Sunny_to_Foggy
# Image:  input2.txt
# Extracted 293 images
# val_psnr: 25.46, val_ssim: 0.9116
# validation time is 5.4380
# ****************************************************************************************************
# Folder:  Sunny_to_Foggy
# Image:  input3.txt
# Extracted 293 images
# val_psnr: 22.50, val_ssim: 0.8847
# validation time is 5.1243
# ****************************************************************************************************
# Folder:  Sunny_to_Foggy
# Image:  input4.txt
# Extracted 293 images
# val_psnr: 19.70, val_ssim: 0.8477
# validation time is 5.8461
# ****************************************************************************************************
# Folder:  Sunny_to_Foggy
# Image:  input5.txt
# Extracted 293 images
# val_psnr: 17.31, val_ssim: 0.8041
# validation time is 5.3185
# ****************************************************************************************************
# Folder:  Sunny_to_Foggy
# Image:  input6.txt
# Extracted 293 images
# val_psnr: 15.32, val_ssim: 0.7575
# validation time is 5.8900
# ****************************************************************************************************
# Folder:  Sunny_to_Foggy
# Image:  input7.txt
# Extracted 293 images
# val_psnr: 13.67, val_ssim: 0.7106
# validation time is 6.4251
# ****************************************************************************************************
# Folder:  Sunny_to_Foggy
# Image:  input8.txt
# Extracted 293 images
# val_psnr: 12.34, val_ssim: 0.6651
# validation time is 6.1398
# ****************************************************************************************************
# Folder:  Sunny_to_Foggy
# Image:  input9.txt
# Extracted 293 images
# val_psnr: 11.29, val_ssim: 0.6191
# validation time is 4.7474
# ****************************************************************************************************
# Folder:  Sunny_to_Rainy
# Image:  input0.txt
# Extracted 217 images
# val_psnr: 26.90, val_ssim: 0.8933
# validation time is 2.5996
# ****************************************************************************************************
# Folder:  Sunny_to_Rainy
# Image:  input1.txt
# Extracted 217 images
# val_psnr: 27.47, val_ssim: 0.8893
# validation time is 3.7447
# ****************************************************************************************************
# Folder:  Sunny_to_Rainy
# Image:  input2.txt
# Extracted 217 images
# val_psnr: 24.30, val_ssim: 0.8510
# validation time is 3.9183
# ****************************************************************************************************
# Folder:  Sunny_to_Rainy
# Image:  input3.txt
# Extracted 217 images
# val_psnr: 20.56, val_ssim: 0.7935
# validation time is 4.1340
# ****************************************************************************************************
# Folder:  Sunny_to_Rainy
# Image:  input4.txt
# Extracted 217 images
# val_psnr: 17.42, val_ssim: 0.7289
# validation time is 4.0214
# ****************************************************************************************************
# Folder:  Sunny_to_Rainy
# Image:  input5.txt
# Extracted 217 images
# val_psnr: 14.93, val_ssim: 0.6639
# validation time is 3.6887
# ****************************************************************************************************
# Folder:  Sunny_to_Rainy
# Image:  input6.txt
# Extracted 217 images
# val_psnr: 12.98, val_ssim: 0.6031
# validation time is 3.8915
# ****************************************************************************************************
# Folder:  Sunny_to_Rainy
# Image:  input7.txt
# Extracted 217 images
# val_psnr: 11.43, val_ssim: 0.5473
# validation time is 3.8172
# ****************************************************************************************************
# Folder:  Sunny_to_Rainy
# Image:  input8.txt
# Extracted 217 images
# val_psnr: 10.20, val_ssim: 0.4963
# validation time is 4.0971
# ****************************************************************************************************
# Folder:  Sunny_to_Rainy
# Image:  input9.txt
# Extracted 217 images
# val_psnr: 9.23, val_ssim: 0.4505
# validation time is 4.8124
# ****************************************************************************************************
# --- Evaluation finish! ---
